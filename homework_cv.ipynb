# %%
# Load the California Housing dataset
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
california_housing = fetch_california_housing(as_frame=True)
# Access the data and target
X = california_housing.data  
y = california_housing.target

# %%
test_size= 0.2
indices = np.arange(X.shape[0])
test_count = int(len(X) * test_size)
list=[]
for n in range(1,6):
    test_indices = indices[(n-1) * test_count : n * test_count]
    train_indices = np.concatenate((indices[:(n-1) * test_count], indices[n * test_count :]))
    X_train, X_test = X.iloc[train_indices], X.iloc[test_indices]
    y_train, y_test = y.iloc[train_indices], y.iloc[test_indices]
    lin_reg= LinearRegression()
    lin_reg.fit(X_train,y_train)
    y_pred=lin_reg.predict(X_test)
    m= r2_score(y_test,y_pred)
    list.append(m)

print(list)
# Out:
# [0.5486632333954597, 0.4682069086053662, 0.5507843423337782, 0.5369870266519767, 0.6605140591531983]
